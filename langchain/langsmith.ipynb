# %%
  from transformers import pipeline

pipe = pipeline(
    model="lxyuan/distilbert-base-multilingual-cased-sentiments-student", 
    return_all_scores=True
)
pipe("It is great to see athletes promoting awareness for climate change.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 from transformers import pipeline
# ----> 3 pipe = pipeline(
#       4   model="lxyuan/distilbert-base-multilingual-cased-sentiments-student",
#       5   return_all_scores=True
#       6 )
#       7 pipe("It is great to see athletes promoting awareness for climate change.")
#
# File ~/Desktop/syncwise_beta/venv/lib/python3.10/site-packages/transformers/pipelines/__init__.py:870, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     868 if isinstance(model, str) or framework is None:
#     869     model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> 870     framework, model = infer_framework_load_model(
# ...
