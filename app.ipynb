# %%
import os.path
import time
import gmail
import base64 
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
import torch
from transformers import AutoModel, AutoTokenizer
from datasets import load_dataset
from torch.utils.data import DataLoader, TensorDataset
mail_data = { 'from': [], 'snippet': [],'topic': [], }

# If modifying these scopes, delete the file token.json.
SCOPES = ["https://mail.google.com/"]

def get_authentication():

  creds = None
  # The file token.json stores the user's access and refresh tokens, and is
  # created automatically when the authorization flow completes for the first
  # time.
  if os.path.exists("token.json"):
    
    creds = Credentials.from_authorized_user_file("token.json", SCOPES)

  # If there are no (valid) credentials available, let the user log in.
  if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
      creds.refresh(Request())
    else:
      flow = InstalledAppFlow.from_client_secrets_file(
          "./syncwise_beta/mail/storage/credentials.json", SCOPES
      )
      creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open("token.json", "w") as token:
      token.write(creds.to_json())
  return creds

from transformers import AutoModelForSequenceClassification
from scipy.special import expit
from transformers import AutoTokenizer, AutoConfig
import numpy as np
from scipy.special import softmax
# Preprocess text (username and link placeholders)





def check_mail(creds):
    try:
        # Call the Gmail API
        service = build('gmail', 'v1', credentials=creds)

        # Get unread messages
        
        results = service.users().messages().list(userId='me', labelIds=['INBOX'], q="is:unread", maxResults=500).execute()
        messages = results.get('messages', [])

        if not messages:
            print("You have no new messages")
        else:
            print(f"You have {len(messages)} unread messages.")
            no_mssg = input("Enter the number of unread messages you want to view ")
            new_message_choice = "y"
            if new_message_choice.startswith("y"):
                mss_count = 0
                for message in messages[:min(25, int(no_mssg))]:
                    mss_count += 1
                    msg = service.users().messages().get(userId='me', id=message['id']).execute()
                    email_data = msg['payload']['headers']

                    for values in email_data:
                        if values["name"] == "From":
                            from_name = values["value"]
                            
                            time.sleep(1)
                            mail_data["from"].append({from_name})
                            mail_data["snippet"].append(msg['snippet'])
                            mail_data['topic'].append((classify(str(mail_data['snippet']))))


            else:
                print("Good-Bye:)")

    except HttpError as error:
        # TODO(developer) - Handle errors from Gmail API.
        print(f"An error occurred: {error}")



def main():
    creds = get_authentication()
    #print( "Email : " + get_profile(creds))
    check_mail(creds)
    for i, (sender, content, topic) in enumerate(zip(mail_data['from'], mail_data['snippet'], mail_data['topic'])):
      print(f"\nNumber - {i+1}")
      print(f"From: {list(sender)[0]}")
      print(f"Content: {content}")
      print(f"Topic: {topic}")



if __name__ == "__main__":
    main()
# Out:
# You have 500 unread messages.
#
# Number - 1
# From: LinkedIn <jobs-listings@linkedin.com>
# Content: Your skills may be a good match for this job ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏
# Topic: Will build the transformers soon
#
# Number - 2
# From: Unstop Internships <noreply@dare2compete.news>
# Content: Tap here to view the opportunities! Formerly Dare2Compete Software Engineer Internship Software Engineer Internship S&amp;P Global Inc. Stipend: INR 45k/month(via glassdoor) Apply now Digital Marketing
# Topic: Will build the transformers soon
#
# Number - 3
# From: adidas Online Store <communication@comm.adidas.in>
# Content: Company Logo MEN WOMEN KIDS STORE FINDER Emailer EOSS Emailer EOSS Emailer EOSS Emailer EOSS The world of addidas apps Privacy Unsubscribe adidas.co.in © 2024 adidas Data Controllers: adidas AG
# Topic: Will build the transformers soon
#
# Number - 4
# From: LinkedIn <messages-noreply@linkedin.com>
# Content: Rouble Chadha sent you a message 3 days ago: &quot;How about you? What are you currently working on?&quot;. Reply? LinkedIn Aayush Sonkar Rouble Chadha sent you a message 3 days ago: &quot;How about
# Topic: Will build the transformers soon
#
# Number - 5
# From: Mukesh Kumar via LinkedIn <newsletters-noreply@linkedin.com>
# Content: What&#39;s Poppin&#39;, Business Buffs? OpsDaddy here, your go-to AI Consultant, ready… ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏
# Topic: Will build the transformers soon
#
# Number - 6
# From: Rajat Goyal <invitations@linkedin.com>
# Content: Aayush, respond to Rajat&#39;s invite now. ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏
# Topic: Will build the transformers soon
#
# Number - 7
# From: Sanya Choudhary <invitations@linkedin.com>
# Content: Aayush, respond to Sanya&#39;s invite now. ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏
# Topic: Will build the transformers soon
#
# Number - 8
# From: "Levi's" <levis@mailer.levi.in>
# Content: Shop the latest fits. It&#39;s time for a refresh! levis levis levis If you&#39;d like to unsubscribe and stop receiving these emails click here .
# Topic: Will build the transformers soon
#
# Number - 9
# From: Team Unstop <noreply@dare2compete.news>
# Content: Hi Aayush, Imagine standing in the playground and walking up to the winners podium to receive your well-deserved trophy while recruiters from your favourite brands watch you. Sounds too good to be true
# Topic: Will build the transformers soon
#
# Number - 10
# From: Medium Daily Digest <noreply@medium.com>
# Content: Aayuhs Stories for Aayuhs @11tworldaayush·Become a member Medium daily digest Today&#39;s highlights Michael Lamptey Michael Lamptey· 6 min read I Tried 15 Productivity Apps And Found An AI App That
# Topic: Will build the transformers soon
#
# Number - 11
# From: George - TeleportHQ <george@emails.teleporthq.io>
# Content: A few resources to set you up for success ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌
# Topic: Will build the transformers soon
#
# Number - 12
# From: TeleportHQ Team <hello@teleporthq.io>
# Content: Teleport logo Headless CMS Integrations are live in BETA - Go to beta.teleporthq.io Create, Code &amp; Publish. Together Build your websites visually, add data from a Headless CMS, and publish. All
# Topic: Will build the transformers soon
#
# Number - 13
# From: Serge Gatari <serge@clientacquisition.ca>
# Content: Partnering up with YT influencers ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌
# Topic: Will build the transformers soon
#
# Number - 14
# From: Christian from Consensus <Christian@consensus.app>
# Content: This channel will be a place to suggest product improvements, share interesting content, and connect with other amazing people using the product! View this email in your browser Hello! It&#39;s great
# Topic: Will build the transformers soon
#
# Number - 15
# From: edX Team <noreply@sfmc.edx.org>
# Content: Make self-improvement your top priority. {preheader_text} edX Logo Courses / Programs / My Account Tackle new tools and software in 2024. Are you looking to add more to your résumé and portfolio in
# Topic: Will build the transformers soon
#
# Number - 16
# From: Jon Penberthy <support@adclients.com>
# Content: aayush Tomorrow is a BIG day. We&#39;re releasing the full details for AdCon2024! But only to those on the priority notification list. The past week has been crazy, we&#39;ve had people banging down
# Topic: Will build the transformers soon
#
# Number - 17
# From: Newton School <no-reply@newtonschool.co.in>
# Content: Newton School cordially invites you to be a part of our monthly coding contest. The challenge will go live on 29th January 2024 at 9 PM IST. Win Prizes Worth ₹30000 Apply Now Highlights of contest: You
# Topic: Will build the transformers soon
#
# Number - 18
# From: Grammarly Premium <hello@mail.grammarly.com>
# Content: Master clarity and more with Premium&#39;s expert assistance. ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌
# Topic: Will build the transformers soon
#
# Number - 19
# From: Shivam Rajput via LinkedIn <invitations@linkedin.com>
# Content: See Shivam&#39;s connections, experience, and more LinkedIn Aayush Sonkar Shivam Rajput has accepted your invitation. Let&#39;s start a conversation. Shivam Rajput Shivam Rajput Undergrad at Indian
# Topic: Will build the transformers soon
#
# Number - 20
# From: Newton School <no-reply@newtonschool.co.in>
# Content: Newton School cordially invites you to be a part of our monthly coding contest. The challenge will go live on 29th January 2024 at 9 PM IST. Win Prizes Worth ₹30000 Apply Now Highlights of contest: You
# Topic: Will build the transformers soon
#
# Number - 21
# From: Apollo <support@meetapollo.io>
# Content: Apollo Your Apollo email credit limit has been refreshed! You can now use 50 leads and your next credit refresh of 50 leads will be on February 28, 2024, but here are some tips to maximize your value
# Topic: Will build the transformers soon
#
# Number - 22
# From: Unstop Internships <noreply@dare2compete.news>
# Content: Tap here to view the opportunities! Formerly Dare2Compete Cybersecurity Internship (Blue Team) Cybersecurity Internship (Blue Team) Siemens Healthineers Stipend: INR 20k/month (via glassdoor) Apply now
# Topic: Will build the transformers soon
#
# Number - 23
# From: Quora Digest <english-personalized-digest@quora.com>
# Content: First, don&#39;t put pressure on yourself for not having a “bank balance” or “assets”. It&#39;s important to know that all these are still achievable only if you have a sane mind and good health. Try g
# Topic: Will build the transformers soon
#
# Number - 24
# From: Navya Tripathi via LinkedIn <invitations@linkedin.com>
# Content: See Navya&#39;s connections, experience, and more LinkedIn Aayush Sonkar Navya Tripathi has accepted your invitation. Let&#39;s start a conversation. Navya Tripathi Navya Tripathi Sophomore at Indian
# Topic: Will build the transformers soon
#
# Number - 25
# From: "Rathina from Crio.Do" <team@crio.in>
# Content: Hey Aayush, What do Data Structures &amp; Algorithms (DSA) and System Design have in common? They play a pivotal role in cracking SDE interviews! 🚀 While DSA enhances your problem-solving abilities,
# Topic: Will build the transformers soon

# %%
from transformers import pipeline

def classify(prompt):
    pipe = pipeline("text-classification", model="cardiffnlp/tweet-topic-21-multi")
    returned = pipe(prompt)[0]['label']
    return (returned)

# %%
classify("hello world")
# Out:
# 'diaries_&_daily_life'
